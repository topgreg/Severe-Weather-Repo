# %% [markdown]
# # Severe Weather Capstone - EDA
#
# Greg Welliver

# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
import warnings
from scipy import stats
import re
from glob import glob, iglob
from datetime import datetime
from wordcloud import WordCloud, STOPWORDS

# Seaborn settings
sns.set_context('notebook')
#sns.set_style("whitegrid")
#sns.set_style("white")
style_set = sns.set_style('whitegrid')
pd.options.display.float_format = '{:,}'.format
color_choice1 = 'plum'
color_choice2 = 'lightblue'
color_choice3 = 'lightgreen'
#ax.yaxis.set_major_formatter('{x:,.0f}')
#sns.set_context('notebook', font_scale = 4)

# %matplotlib inline
import pandas as pd
#from mpl_toolkits.basemap import Basemap

import geopandas as gpd
from shapely.geometry import Point, Polygon
import contextily as ctx

from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Load the data

# %%
# load data
#df = pd.read_csv("../Data/StormEvents_details-ftp_v1.0_d2001_c20220425.csv")
#df = pd.read_parquet("../Data/all_storm_data9.pqt")
df = pd.read_parquet("../Data/all_storm_data11.pqt")
state_population = pd.read_csv("../Data/state_population.csv")

# %%
df.head(10).T
# Out:
#                                                                    0  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                      2118
# STATE                                                         NEVADA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                 High Wind
# BEGIN_DATE_TIME                                  2022-02-20 21:18:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       36.0
# MAGNITUDE_TYPE                                                    MS
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Strong winds increased ahead of an approaching...
# EVENT_NARRATIVE    Station (UP994) 3.1 SE West Wendover, Elevatio...
# ST_CT_FIPS                                                     32033
# DURATION                                                        60.0
# STORM_AREA                                                       NaN
# PopDensity                                              0.4236221825
# Population                                                   9,078.0
# HPI                                                         34,169.0
#
#                                                                    1  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       800
# STATE                                                         NEVADA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-21 08:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low centered over northern and central Nevad...
# EVENT_NARRATIVE    Thirteen inches fell at station (BCSN2) Big Cr...
# ST_CT_FIPS                                                     32037
# DURATION                                                     1,560.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    2  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       200
# STATE                                                         NEVADA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-22 02:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low centered over northern and central Nevad...
# EVENT_NARRATIVE    Fifteen inches fell at station (TJMN2) Toe Jam...
# ST_CT_FIPS                                                     32031
# DURATION                                                       420.0
# STORM_AREA                                                       NaN
# PopDensity                                               27.60229777
# Population                                                 486,489.0
# HPI                                                        118,374.0
#
#                                                                    3  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                      1609
# STATE                                                 ATLANTIC SOUTH
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Waterspout
# BEGIN_DATE_TIME                                  2022-02-18 16:09:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      30.05
# BEGIN_LON                                                     -81.17
# EPISODE_NARRATIVE  Pre-frontal showers and thunderstorms moved so...
# EVENT_NARRATIVE    A brief waterspout was observed offshore of So...
# ST_CT_FIPS                                                     87452
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    4  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                         0
# STATE                                                 AMERICAN SAMOA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Rain
# BEGIN_DATE_TIME                                  2022-02-02 00:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                             50,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    -14.333
# BEGIN_LON                                                  -170.7157
# EPISODE_NARRATIVE  A surface trough over the Islands held  the po...
# EVENT_NARRATIVE    Over a 24-hour period, WSO Pago Pago recorded ...
# ST_CT_FIPS                                                     97002
# DURATION                                                     1,440.0
# STORM_AREA                                      0.006299999999999528
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    5  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       500
# STATE                                                 AMERICAN SAMOA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Rain
# BEGIN_DATE_TIME                                  2022-02-12 05:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                   -14.3364
# BEGIN_LON                                                  -170.7856
# EPISODE_NARRATIVE  A surface trough that remained anchored over t...
# EVENT_NARRATIVE    EOC reported a landslide near Agugulu enroute ...
# ST_CT_FIPS                                                     97002
# DURATION                                                     1,020.0
# STORM_AREA                                      0.005300000000000082
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    6  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       100
# STATE                                                         KANSAS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                              Winter Storm
# BEGIN_DATE_TIME                                  2022-02-01 01:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Snow developed during the overnight hours on F...
# EVENT_NARRATIVE    KVOE radio station measured 5 inches of snow i...
# ST_CT_FIPS                                                     20054
# DURATION                                                       600.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    7  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       100
# STATE                                                         KANSAS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                              Winter Storm
# BEGIN_DATE_TIME                                  2022-02-01 01:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Snow developed during the overnight hours on F...
# EVENT_NARRATIVE    A combination of CoCoRaHS, COOP and NWS report...
# ST_CT_FIPS                                                     20039
# DURATION                                                       660.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    8  \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       200
# STATE                                                  MASSACHUSETTS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-13 02:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low pressure system tracked offshore of Sout...
# EVENT_NARRATIVE    Snowfall was generally 5 to 9 inches. The high...
# ST_CT_FIPS                                                     25012
# DURATION                                                     1,680.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                    9
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       400
# STATE                                                  MASSACHUSETTS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-13 04:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low pressure system tracked offshore of Sout...
# EVENT_NARRATIVE    Snowfall was generally 6 to 8 inches. The high...
# ST_CT_FIPS                                                     25013
# DURATION                                                     1,680.0
# STORM_AREA                                                       NaN
# PopDensity                                               293.5650603
# Population                                                 465,834.0
# HPI                                                        104,146.0

# %% [markdown]
# ### This map shows the density of storms across the US.

# %%
df_map = df[['BEGIN_LAT', 'BEGIN_LON']]
df_map = df_map.dropna()
df_map.head().reset_index().drop(['index'], axis=1)
BBox = ((-125,   -65,      
         24, 53))
fig, ax = plt.subplots(figsize = (25,15))
ax.scatter(df_map.BEGIN_LON, df_map.BEGIN_LAT, zorder=1, alpha= .5, c='g', s=.2)
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
;
# Out:
# ''

# %% [markdown]
# ### Look at the trend of reported storms over time

# %%
fig, ax = plt.subplots(figsize = (12 , 6))
plt.title("Number of reported storms per year")
sns.countplot(x='YEAR', data=df, color=color_choice1)
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter('{x:,.0f}')
;
# Out:
# ''

# %%
# the large increase from 2020 to 2021 is worth looking into
len(df[df['YEAR'] == 2021]) - len(df[df['YEAR'] == 2020])
# Out:
# 61249

# %%
df[df['YEAR'] == 2020].EVENT_TYPE.value_counts()[:10]
# Out:
# Thunderstorm Wind           19314
# Hail                         7670
# High Wind                    3669
# Flash Flood                  3571
# Winter Weather               2910
# Marine Thunderstorm Wind     2887
# Flood                        2703
# Drought                      2244
# Winter Storm                 2094
# Heavy Snow                   1792
# Name: EVENT_TYPE, dtype: int64

# %%
df[df['YEAR'] == 2021].EVENT_TYPE.value_counts()[:10]
# Out:
# Thunderstorm Wind           31066
# Hail                        12544
# Flash Flood                  9594
# High Wind                    9194
# Drought                      8166
# Winter Weather               7828
# Winter Storm                 5890
# Marine Thunderstorm Wind     5368
# Heavy Snow                   4468
# Flood                        4062
# Name: EVENT_TYPE, dtype: int64

# %% [markdown]
# #### Comment on the large change from 2020 to 2021:
# I was not able to find if there was a change in reporting methodology that drove the large increase year-over-year.  Looking at the storm event data, it does not appear to be isolated to any one particular type of storm - there is an increase across a number of different categories. It seems unlikely that the number of storms actually doubled year-over-year, so will monitor the potential impact of this.

# %% [markdown]
# ### Let's look at what months of the year storms tend to occur

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
fig, ax = plt.subplots(figsize = (12 , 6))
plt.title("Storm Count by Month")
sns.countplot(x='MONTH_NAME', data=df, color=color_choice2, order=month_order)
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter('{x:,.0f}')
;
# Out:
# ''

# %% [markdown]
# ### Let's look at storms by state

# %%
df_state = df[df.groupby('STATE')['STATE'].transform('size') > 2000].reset_index(drop=True)

fig, ax = plt.subplots(figsize = (12 , 18))
plt.title("Storm Count by State / Location")

sns.countplot(y='STATE', data=df_state, color=color_choice1, order=df_state['STATE'].value_counts().index)
ax.xaxis.set_major_formatter('{x:,.0f}')
;
# Out:
# ''

# %% [markdown]
# ### Let's look at storm counts by type

# %%
df_events = df[df.groupby('EVENT_TYPE')['EVENT_TYPE'].transform('size') > 2000].reset_index(drop=True)

fig, ax = plt.subplots(figsize = (12 , 8))
plt.title("Storm Count by Type")

sns.countplot(x='EVENT_TYPE', data=df_events, color=color_choice2, order=df_events['EVENT_TYPE'].value_counts().index)
plt.xticks(rotation=90)
ax.yaxis.set_major_formatter('{x:,.0f}')
;
# Out:
# ''

# %% [markdown]
# ### Let's take a closer look at our dependent variable, Property Damage ('DAMAGE_PROPERTY')

# %%
df['DAMAGE_PROPERTY'].describe()
# Out:
# count           1,555,647.0
# mean     340,964.7113966086
# std     33,310,968.63361031
# min                     0.0
# 25%                     0.0
# 50%                     0.0
# 75%                     0.0
# max        17,900,000,000.0
# Name: DAMAGE_PROPERTY, dtype: float64

# %%
df.sort_values('DAMAGE_PROPERTY', ascending=False).T
# Out:
#                                                              1490928  \
# BEGIN_YEARMONTH                                               200508
# BEGIN_TIME                                                       200
# STATE                                                      LOUISIANA
# YEAR                                                            2005
# MONTH_NAME                                                    August
# EVENT_TYPE                                          Storm Surge/Tide
# BEGIN_DATE_TIME                                  2005-08-29 02:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                     17,900,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Storm surge damage in southeast Louisiana, esp...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     22062
# DURATION                                                       900.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              1423421  \
# BEGIN_YEARMONTH                                               201811
# BEGIN_TIME                                                       633
# STATE                                                     CALIFORNIA
# YEAR                                                            2018
# MONTH_NAME                                                  November
# EVENT_TYPE                                                  Wildfire
# BEGIN_DATE_TIME                                  2018-11-08 06:33:00
# INJURIES_DIRECT                                                   12
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                     86
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                     17,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  An extended period of dry weather through the ...
# EVENT_NARRATIVE    The Camp Fire began on the morning of November...
# ST_CT_FIPS                                                     06066
# DURATION                                                    24,987.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              1144380  \
# BEGIN_YEARMONTH                                               201708
# BEGIN_TIME                                                      2145
# STATE                                                          TEXAS
# YEAR                                                            2017
# MONTH_NAME                                                    August
# EVENT_TYPE                                               Flash Flood
# BEGIN_DATE_TIME                                  2017-08-26 21:45:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                     36
# DEATHS_INDIRECT                                                    2
# DAMAGE_PROPERTY                                     10,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                             Heavy Rain / Tropical System
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    29.5688
# BEGIN_LON                                                   -95.0139
# EPISODE_NARRATIVE  Harvey made landfall as a category 4 hurricane...
# EVENT_NARRATIVE    There were numerous water rescues within Houst...
# ST_CT_FIPS                                                     48201
# DURATION                                                     4,335.0
# STORM_AREA                                      0.033799999999999386
# PopDensity                                              1,042.130651
# Population                                               4,731,129.0
# HPI                                                         49,608.0
#
#                                                              1504196  \
# BEGIN_YEARMONTH                                               200510
# BEGIN_TIME                                                       700
# STATE                                                        FLORIDA
# YEAR                                                            2005
# MONTH_NAME                                                   October
# EVENT_TYPE                                       Hurricane (Typhoon)
# BEGIN_DATE_TIME                                  2005-10-24 07:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      1
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                     10,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Wilma was a classic October hurricane which st...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     12068
# DURATION                                                       300.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              1143765  \
# BEGIN_YEARMONTH                                               201708
# BEGIN_TIME                                                      2200
# STATE                                                          TEXAS
# YEAR                                                            2017
# MONTH_NAME                                                    August
# EVENT_TYPE                                               Flash Flood
# BEGIN_DATE_TIME                                  2017-08-26 22:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      3
# DEATHS_INDIRECT                                                    3
# DAMAGE_PROPERTY                                     10,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                             Heavy Rain / Tropical System
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    29.4972
# BEGIN_LON                                                   -94.9164
# EPISODE_NARRATIVE  Harvey made landfall as a category 4 hurricane...
# EVENT_NARRATIVE    There were numerous water rescues across weste...
# ST_CT_FIPS                                                     48167
# DURATION                                                     4,440.0
# STORM_AREA                                       0.11720000000000041
# PopDensity                                               333.2739017
# Population                                                 350,673.0
# HPI                                                         40,473.0
#
#                                                              1143599  \
# BEGIN_YEARMONTH                                               201708
# BEGIN_TIME                                                      1840
# STATE                                                          TEXAS
# YEAR                                                            2017
# MONTH_NAME                                                    August
# EVENT_TYPE                                               Flash Flood
# BEGIN_DATE_TIME                                  2017-08-26 18:40:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      3
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                      8,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                             Heavy Rain / Tropical System
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    29.4493
# BEGIN_LON                                                   -96.0027
# EPISODE_NARRATIVE  Harvey made landfall as a category 4 hurricane...
# EVENT_NARRATIVE    There were numerous road closures around the R...
# ST_CT_FIPS                                                     48157
# DURATION                                                     4,400.0
# STORM_AREA                                        0.3582000000000001
# PopDensity                                               331.3226402
# Population                                                 822,779.0
# HPI                                                          4,045.0
#
#                                                              916898   \
# BEGIN_YEARMONTH                                               201210
# BEGIN_TIME                                                       500
# STATE                                                     NEW JERSEY
# YEAR                                                            2012
# MONTH_NAME                                                   October
# EVENT_TYPE                                             Coastal Flood
# BEGIN_DATE_TIME                                  2012-10-29 05:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                      7,500,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Post Tropical Storm Sandy was the costliest na...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     34026
# DURATION                                                     1,020.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              1143761  \
# BEGIN_YEARMONTH                                               201708
# BEGIN_TIME                                                      2000
# STATE                                                          TEXAS
# YEAR                                                            2017
# MONTH_NAME                                                    August
# EVENT_TYPE                                               Flash Flood
# BEGIN_DATE_TIME                                  2017-08-27 20:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      3
# DEATHS_INDIRECT                                                    1
# DAMAGE_PROPERTY                                      7,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                             Heavy Rain / Tropical System
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    30.0408
# BEGIN_LON                                                   -95.2487
# EPISODE_NARRATIVE  Harvey made landfall as a category 4 hurricane...
# EVENT_NARRATIVE    Tropical Storm Harvey brought heavy rains and ...
# ST_CT_FIPS                                                     48339
# DURATION                                                     3,120.0
# STORM_AREA                                       0.07600000000000051
# PopDensity                                               205.3210869
# Population                                                 620,451.0
# HPI                                                         37,451.0
#
#                                                              46711    \
# BEGIN_YEARMONTH                                               202209
# BEGIN_TIME                                                      1405
# STATE                                                        FLORIDA
# YEAR                                                            2022
# MONTH_NAME                                                 September
# EVENT_TYPE                                                 Hurricane
# BEGIN_DATE_TIME                                  2022-09-28 14:05:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                     60
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                      7,000,000,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Hurricane Ian formed in the central Caribbean ...
# EVENT_NARRATIVE    The highest wind reported in Lee County from H...
# ST_CT_FIPS                                                     12165
# DURATION                                                         0.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              702325   ...  \
# BEGIN_YEARMONTH                                               202209  ...
# BEGIN_TIME                                                      1405  ...
# STATE                                                        FLORIDA  ...
# YEAR                                                            2022  ...
# MONTH_NAME                                                 September  ...
# EVENT_TYPE                                                 Hurricane  ...
# BEGIN_DATE_TIME                                  2022-09-28 14:05:00  ...
# INJURIES_DIRECT                                                    0  ...
# INJURIES_INDIRECT                                                  0  ...
# DEATHS_DIRECT                                                     60  ...
# DEATHS_INDIRECT                                                    0  ...
# DAMAGE_PROPERTY                                      7,000,000,000.0  ...
# MAGNITUDE                                                        0.0  ...
# MAGNITUDE_TYPE                                                  None  ...
# FLOOD_CAUSE                                                     None  ...
# TOR_F_SCALE                                                     None  ...
# TOR_LENGTH                                                       0.0  ...
# TOR_WIDTH                                                        0.0  ...
# BEGIN_LAT                                                        NaN  ...
# BEGIN_LON                                                        NaN  ...
# EPISODE_NARRATIVE  Hurricane Ian formed in the central Caribbean ...  ...
# EVENT_NARRATIVE    The highest wind reported in Lee County from H...  ...
# ST_CT_FIPS                                                     12165  ...
# DURATION                                                         0.0  ...
# STORM_AREA                                                       NaN  ...
# PopDensity                                                       NaN  ...
# Population                                                       NaN  ...
# HPI                                                              NaN  ...
#
#                                                              582068   \
# BEGIN_YEARMONTH                                               201305
# BEGIN_TIME                                                      2155
# STATE                                                          TEXAS
# YEAR                                                            2013
# MONTH_NAME                                                       May
# EVENT_TYPE                                           Cold/Wind Chill
# BEGIN_DATE_TIME                                  2013-05-01 21:55:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A cold front moved through the Texas Panhandle...
# EVENT_NARRATIVE    An overnight low of 32 degrees was reported in...
# ST_CT_FIPS                                                     48005
# DURATION                                                       645.0
# STORM_AREA                                                       NaN
# PopDensity                                               42.39912091
# Population                                                  86,394.0
# HPI                                                         23,036.0
#
#                                                              582058   \
# BEGIN_YEARMONTH                                               201304
# BEGIN_TIME                                                         0
# STATE                                                          TEXAS
# YEAR                                                            2013
# MONTH_NAME                                                     April
# EVENT_TYPE                                                   Drought
# BEGIN_DATE_TIME                                  2013-04-01 00:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Drought conditions worsened during the month o...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     48032
# DURATION                                                    43,199.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              582067   \
# BEGIN_YEARMONTH                                               201305
# BEGIN_TIME                                                      2155
# STATE                                                          TEXAS
# YEAR                                                            2013
# MONTH_NAME                                                       May
# EVENT_TYPE                                           Cold/Wind Chill
# BEGIN_DATE_TIME                                  2013-05-01 21:55:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A cold front moved through the Texas Panhandle...
# EVENT_NARRATIVE    An overnight low of 32 degrees was reported in...
# ST_CT_FIPS                                                     48004
# DURATION                                                       645.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                              582066   \
# BEGIN_YEARMONTH                                               201305
# BEGIN_TIME                                                      2155
# STATE                                                          TEXAS
# YEAR                                                            2013
# MONTH_NAME                                                       May
# EVENT_TYPE                                           Cold/Wind Chill
# BEGIN_DATE_TIME                                  2013-05-01 21:55:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A cold front moved through the Texas Panhandle...
# EVENT_NARRATIVE    An overnight low of 30 degrees was reported in...
# ST_CT_FIPS                                                     48003
# DURATION                                                       645.0
# STORM_AREA                                                       NaN
# PopDensity                                               4.584174535
# Population                                                  18,614.0
# HPI                                                         18,313.0
#
#                                                              582065   \
# BEGIN_YEARMONTH                                               201304
# BEGIN_TIME                                                      1609
# STATE                                                    MISSISSIPPI
# YEAR                                                            2013
# MONTH_NAME                                                     April
# EVENT_TYPE                                                   Tornado
# BEGIN_DATE_TIME                                  2013-04-18 16:09:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                      EF0
# TOR_LENGTH                                                      0.27
# TOR_WIDTH                                                       50.0
# BEGIN_LAT                                                    33.3193
# BEGIN_LON                                                   -90.8568
# EPISODE_NARRATIVE  Gusty southerly winds blew for several days ah...
# EVENT_NARRATIVE    This tornado was photographed in an open field...
# ST_CT_FIPS                                                     28151
# DURATION                                                         1.0
# STORM_AREA                                     0.0020999999999986585
# PopDensity                                               25.08498098
# Population                                                  44,918.0
# HPI                                                         19,139.0
#
#                                                              582064   \
# BEGIN_YEARMONTH                                               201304
# BEGIN_TIME                                                      1422
# STATE                                                       ILLINOIS
# YEAR                                                            2013
# MONTH_NAME                                                     April
# EVENT_TYPE                                                      Hail
# BEGIN_DATE_TIME                                  2013-04-10 14:22:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        2.5
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      39.62
# BEGIN_LON                                                      -87.7
# EPISODE_NARRATIVE  Low pressure tracking along a stationary front...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     17045
# DURATION                                                         1.0
# STORM_AREA                                                       0.0
# PopDensity                                               10.86302996
# Population                                                  16,868.0
# HPI                                                         21,218.0
#
#                                                              582063   \
# BEGIN_YEARMONTH                                               201304
# BEGIN_TIME                                                         0
# STATE                                                          TEXAS
# YEAR                                                            2013
# MONTH_NAME                                                     April
# EVENT_TYPE                                                   Drought
# BEGIN_DATE_TIME                                  2013-04-01 00:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Drought conditions worsened during the month o...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     48037
# DURATION                                                    43,199.0
# STORM_AREA                                                       NaN
# PopDensity                                               40.94769801
# Population                                                  92,903.0
# HPI                                                         32,323.0
#
#                                                              582061   \
# BEGIN_YEARMONTH                                               201304
# BEGIN_TIME                                                         0
# STATE                                                          TEXAS
# YEAR                                                            2013
# MONTH_NAME                                                     April
# EVENT_TYPE                                                   Drought
# BEGIN_DATE_TIME                                  2013-04-01 00:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Drought conditions worsened during the month o...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     48025
# DURATION                                                    43,199.0
# STORM_AREA                                                       NaN
# PopDensity                                               14.33935601
# Population                                                  31,061.0
# HPI                                                         17,222.0
#
#                                                              582060   \
# BEGIN_YEARMONTH                                               201304
# BEGIN_TIME                                                      1418
# STATE                                                       ILLINOIS
# YEAR                                                            2013
# MONTH_NAME                                                     April
# EVENT_TYPE                                                      Hail
# BEGIN_DATE_TIME                                  2013-04-10 14:18:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        1.5
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      39.62
# BEGIN_LON                                                      -87.7
# EPISODE_NARRATIVE  Low pressure tracking along a stationary front...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     17045
# DURATION                                                         1.0
# STORM_AREA                                                       0.0
# PopDensity                                               10.86302996
# Population                                                  16,868.0
# HPI                                                         21,218.0
#
#                                                              1555646
# BEGIN_YEARMONTH                                               200112
# BEGIN_TIME                                                       700
# STATE                                                    PUERTO RICO
# YEAR                                                            2001
# MONTH_NAME                                                  December
# EVENT_TYPE                                               Flash Flood
# BEGIN_DATE_TIME                                  2001-12-22 07:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A cold front became stationary north of Puerto...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     99005
# DURATION                                                       900.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
# [28 rows x 1555647 columns]

# %%
# code to see how many values in the damage property column are more than 3 standard deviations away (proxy for outliers)
data = df["DAMAGE_PROPERTY"]
outliers = []
def detect_outliers_zscore(data):
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    # print(mean, std)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            outliers.append(i)
    return outliers# Driver code
#sample_outliers = detect_outliers_zscore(sample)
sample_outliers = detect_outliers_zscore(data)
print("Outliers from Z-scores method: ", sample_outliers)
# Out:
# Outliers from Z-scores method:  [115000000.0, 300000000.0, 500000000.0, 500000000.0, 7000000000.0, 2000000000.0, 3000000000.0, 1000000000.0, 245000000.0, 115000000.0, 241000000.0, 340000000.0, 495000000.0, 206000000.0, 2200000000.0, 547000000.0, 440000000.0, 1500000000.0, 165000000.0, 123000000.0, 166500000.0, 106000000.0, 146500000.0, 177000000.0, 674000000.0, 3000000000.0, 382000000.0, 2000000000.0, 2500000000.0, 260000000.0, 500000000.0, 1000000000.0, 2500000000.0, 1000000000.0, 240000000.0, 320400000.0, 4000000000.0, 373000000.0, 881000000.0, 250000000.0, 452000000.0, 200000000.0, 500000000.0, 139000000.0, 125000000.0, 200000000.0, 500000000.0, 500000000.0, 750000000.0, 500000000.0, 300000000.0, 500000000.0, 1000000000.0, 750000000.0, 750000000.0, 250000000.0, 250000000.0, 500000000.0, 250000000.0, 500000000.0, 500000000.0, 750000000.0, 750000000.0, 250000000.0, 500000000.0, 500000000.0, 300000000.0, 300000000.0, 2000000000.0, 696400000.0, 1040000000.0, 278600000.0, 155000000.0, 252000000.0, 125000000.0, 347000000.0, 210000000.0, 160000000.0, 1000000000.0, 157000000.0, 133000000.0, 300000000.0, 151100000.0, 150000000.0, 101000000.0, 121690000.0, 250000000.0, 110000000.0, 500000000.0, 137000000.0, 288000000.0, 250000000.0, 125000000.0, 500000000.0, 140000000.0, 253380000.0, 217000000.0, 1800000000.0, 150000000.0, 110000000.
sns.boxplot( y=df["DAMAGE_PROPERTY"] );
plt.show()

# %%
df["DAMAGE_PROPERTY"].value_counts()
# Out:
# 0.0              1208379
# 5,000.0            44298
# 1,000.0            42880
# 10,000.0           37586
# 2,000.0            30523
#                   ...
# 124,000,000.0          1
# 1,710,000.0            1
# 3,850.0                1
# 81,000,000.0           1
# 322,200.0              1
# Name: DAMAGE_PROPERTY, Length: 2060, dtype: int64

# %%
1208379/1558288
# Out:
# 0.7754529329623279

# %% [markdown]
# The dataset also contains a huge number of storms that did not have any property damage - 78% of observations do not have any damage.
# The high number of outliers and high number of zeros make this a fairly irregular dataset.

# %%
sns.histplot(df['DAMAGE_PROPERTY'])
# Out:
# <AxesSubplot:xlabel='DAMAGE_PROPERTY', ylabel='Count'>

# %% [markdown]
# #### Plot with logarithmic scale

# %%
sns.histplot(df['DAMAGE_PROPERTY'])
plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# #### Let's look at top states by damange

# %%
df_states = pd.DataFrame(df.groupby('STATE')['DAMAGE_PROPERTY'].sum().sort_values(ascending=False).reset_index()[:15])
df_states['DAMAGE_PROPERTY'] = df_states['DAMAGE_PROPERTY'] / 1000000000
#df_states

fig, ax = plt.subplots(figsize = (12 , 6))

#plt.figure(figsize=(12,6))
plt.title("Storm Damage by State / Location")
sns.barplot(x = 'STATE', y = 'DAMAGE_PROPERTY', data = df_states,
            color = color_choice1
            )

ax.set_ylabel("Damage (USD Billions)" , size = 12 )
ax.set_xlabel( "State / Location" , size = 12 )
plt.xticks(rotation=90)
;
# Out:
# ''

# %% [markdown]
# #### Let's look at damage by storm type

# %%
df_event = pd.DataFrame(df.groupby('EVENT_TYPE')['DAMAGE_PROPERTY'].sum().sort_values(ascending=False).reset_index()[:15])
df_event['DAMAGE_PROPERTY'] = df_event['DAMAGE_PROPERTY'] / 1000000000
#df_event

fig, ax = plt.subplots(figsize = (12 , 6))

#plt.figure(figsize=(12,6))
plt.title("Storm Damage by Type")
sns.barplot(x = 'EVENT_TYPE', y = 'DAMAGE_PROPERTY', data = df_event,
            color = color_choice2
            )

ax.set_ylabel("Damage (USD Billions)" , size = 12 )
ax.set_xlabel( "Type" , size = 12 )
plt.xticks(rotation=90)
;
# Out:
# ''

# %% [markdown]
# #### Look at distribution of storm beginning time

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize = (12 , 6))
plt.title("Storm Begin Time")
sns.histplot(x='BEGIN_TIME', data=df, color=color_choice3, bins=12)
#plt.xticks(rotation=45)
ax.yaxis.set_major_formatter('{x:,.0f}')
plt.xticks(np.arange(0, 2400+100, 200))
;
# Out:
# ''

# %% [markdown]
# ### Comments
# - The high number of storms between midnight and 2AM could be a reporting peculiarlity.
# - Interestingly, there is a significant concentration of storms beginning in the early and mid-afternoon

# %% [markdown]
# ### Now let's take a look at correlations between variables

# %%
df.corr()
# Out:
#                          BEGIN_YEARMONTH             BEGIN_TIME  \
# BEGIN_YEARMONTH                      1.0   -0.03919869980561563
# DEATHS_INDIRECT    0.0032216253608035243  0.0061491137291117956
# DAMAGE_PROPERTY      0.00958714969484498  0.0025556075351823686
# MAGNITUDE          0.0030076951236850183   0.007053578872191981
# TOR_LENGTH         -0.013466771498288106  -0.020312207274804293
# TOR_WIDTH          -0.015030891242234284  -0.022315111217477458
# BEGIN_LAT           -0.12241304272228958   0.023067129516102753
# BEGIN_LON           -0.03799775422499324  -0.013254759558266218
# DURATION           -0.031661642131576885  -0.021794100423329982
# STORM_AREA         0.0048616103000485925   0.011570487224730242
# PopDensity            0.3246859681750466    0.24186399900957906
# Population                           1.0     0.4178666094788698
# HPI                   0.4178666094788698                    1.0

# %%
# set up dataframe for correlation matrix
df_corr = df[['INJURIES_DIRECT', 'INJURIES_INDIRECT','DEATHS_DIRECT', 'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'MAGNITUDE', 'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_LAT','BEGIN_LON', 'DURATION', 'STORM_AREA', 'PopDensity', 'Population', 'HPI']]

# %%
corrmat = df_corr.corr()
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(round(corrmat,2), annot=True, ax=ax, cmap='magma',fmt='.2f',
                 linewidths=.05)

f.subplots_adjust(top=0.93)

# %% [markdown]
# ### Comments:
# - there aren't any strong correlations with the dependent variable.  I'll try removing some of the extreme values

# %%
# sort values by higest to lowest to remove some of the outliers
df2 = df.sort_values('DAMAGE_PROPERTY', ascending=False)

# %%
# remove top 10,000 values
df2 = df2[10000:]

# %%
# remove all obserations with zero property damage
df2 = df2[df2['DAMAGE_PROPERTY'] > 0]

# %%
sns.boxplot( y=df2["DAMAGE_PROPERTY"] );
plt.show()

# %% [markdown]
# #### This improved the boxplot somewhat, although it is still certainly not a normal distrubtion

# %%
df_corr2 = df2[['INJURIES_DIRECT', 'INJURIES_INDIRECT','DEATHS_DIRECT', 'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'MAGNITUDE', 'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_LAT','BEGIN_LON', 'DURATION', 'STORM_AREA', 'PopDensity', 'Population', 'HPI']]

# %%
corrmat = df_corr2.corr()
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(round(corrmat,2), annot=True, ax=ax, cmap='magma',fmt='.2f',
                 linewidths=.05)

f.subplots_adjust(top=0.93)

# %% [markdown]
# ### Comments:
# - This did appear to improve the correlation of some variables with property damage

# %% [markdown]
# #### For fun, create a word cloud of episode narrative

# %%
### word cloud
# df['EPISODE_NARRATIVE'] = df['EPISODE_NARRATIVE'].astype('str')
# title_corpus = ' '.join(df['EPISODE_NARRATIVE'])
# title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(title_corpus)
# plt.figure(figsize=(16,8))
# plt.imshow(title_wordcloud)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# scratch notes

# %%
# do a log norm of this plot
# try doing KDE
# try Light GBM and XGBoost
# tweedie distribution -
