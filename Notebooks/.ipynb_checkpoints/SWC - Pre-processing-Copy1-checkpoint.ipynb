# %% [markdown]
# # Severe Weather - Pre-processing
#
# Greg Welliver

# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.ticker as plticker
import seaborn as sns
sns.set()
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
import warnings
from scipy import stats
import matplotlib as mpl
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap
# %matplotlib inline


import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from scipy import stats

from sklearn import linear_model, preprocessing, tree, svm, datasets, metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score, auc, mean_squared_error, r2_score, f1_score, log_loss
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder as OHE
import sklearn.model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

import xgboost
from xgboost import XGBClassifier
import warnings
from subprocess import call
from IPython.display import Image
from datetime import datetime, timedelta, date
import os
import plotly.graph_objects as go
import itertools
from io import StringIO  
import pydotplus
import sweetviz 

# Seaborn settings
sns.set_context('notebook')
#sns.set_style("whitegrid")
#sns.set_style("white")
style_set = sns.set_style('whitegrid')
pd.options.display.float_format = '{:,}'.format
color_choice1 = 'plum'
color_choice2 = 'lightblue'
color_choice3 = 'lightgreen'
#ax.yaxis.set_major_formatter('{x:,.0f}')
#sns.set_context('notebook', font_scale = 4)


# %matplotlib inline
import pandas as pd
#from mpl_toolkits.basemap import Basemap


import geopandas as gpd
from shapely.geometry import Point, Polygon
import contextily as ctx

from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Load the data

# %%
# load data
df = pd.read_parquet("../Data/all_storm_data11.pqt")
#df = pd.read_csv("../Data/all_storm_data4.csv")

# %%
df.head(40).T
# Out:
#                                                                   0   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                      2118
# STATE                                                         NEVADA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                 High Wind
# BEGIN_DATE_TIME                                  2022-02-20 21:18:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       36.0
# MAGNITUDE_TYPE                                                    MS
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Strong winds increased ahead of an approaching...
# EVENT_NARRATIVE    Station (UP994) 3.1 SE West Wendover, Elevatio...
# ST_CT_FIPS                                                     32033
# DURATION                                                        60.0
# STORM_AREA                                                       NaN
# PopDensity                                              0.4236221825
# Population                                                   9,078.0
# HPI                                                         34,169.0
#
#                                                                   1   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       800
# STATE                                                         NEVADA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-21 08:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low centered over northern and central Nevad...
# EVENT_NARRATIVE    Thirteen inches fell at station (BCSN2) Big Cr...
# ST_CT_FIPS                                                     32037
# DURATION                                                     1,560.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   2   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       200
# STATE                                                         NEVADA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-22 02:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low centered over northern and central Nevad...
# EVENT_NARRATIVE    Fifteen inches fell at station (TJMN2) Toe Jam...
# ST_CT_FIPS                                                     32031
# DURATION                                                       420.0
# STORM_AREA                                                       NaN
# PopDensity                                               27.60229777
# Population                                                 486,489.0
# HPI                                                        118,374.0
#
#                                                                   3   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                      1609
# STATE                                                 ATLANTIC SOUTH
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Waterspout
# BEGIN_DATE_TIME                                  2022-02-18 16:09:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      30.05
# BEGIN_LON                                                     -81.17
# EPISODE_NARRATIVE  Pre-frontal showers and thunderstorms moved so...
# EVENT_NARRATIVE    A brief waterspout was observed offshore of So...
# ST_CT_FIPS                                                     87452
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   4   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                         0
# STATE                                                 AMERICAN SAMOA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Rain
# BEGIN_DATE_TIME                                  2022-02-02 00:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                             50,000.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    -14.333
# BEGIN_LON                                                  -170.7157
# EPISODE_NARRATIVE  A surface trough over the Islands held  the po...
# EVENT_NARRATIVE    Over a 24-hour period, WSO Pago Pago recorded ...
# ST_CT_FIPS                                                     97002
# DURATION                                                     1,440.0
# STORM_AREA                                      0.006299999999999528
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   5   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       500
# STATE                                                 AMERICAN SAMOA
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Rain
# BEGIN_DATE_TIME                                  2022-02-12 05:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                   -14.3364
# BEGIN_LON                                                  -170.7856
# EPISODE_NARRATIVE  A surface trough that remained anchored over t...
# EVENT_NARRATIVE    EOC reported a landslide near Agugulu enroute ...
# ST_CT_FIPS                                                     97002
# DURATION                                                     1,020.0
# STORM_AREA                                      0.005300000000000082
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   6   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       100
# STATE                                                         KANSAS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                              Winter Storm
# BEGIN_DATE_TIME                                  2022-02-01 01:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Snow developed during the overnight hours on F...
# EVENT_NARRATIVE    KVOE radio station measured 5 inches of snow i...
# ST_CT_FIPS                                                     20054
# DURATION                                                       600.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   7   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       100
# STATE                                                         KANSAS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                              Winter Storm
# BEGIN_DATE_TIME                                  2022-02-01 01:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  Snow developed during the overnight hours on F...
# EVENT_NARRATIVE    A combination of CoCoRaHS, COOP and NWS report...
# ST_CT_FIPS                                                     20039
# DURATION                                                       660.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   8   \
# BEGIN_YEARMONTH                                               202202
# BEGIN_TIME                                                       200
# STATE                                                  MASSACHUSETTS
# YEAR                                                            2022
# MONTH_NAME                                                  February
# EVENT_TYPE                                                Heavy Snow
# BEGIN_DATE_TIME                                  2022-02-13 02:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low pressure system tracked offshore of Sout...
# EVENT_NARRATIVE    Snowfall was generally 5 to 9 inches. The high...
# ST_CT_FIPS                                                     25012
# DURATION                                                     1,680.0
# STORM_AREA                                                       NaN
# PopDensity                                                       NaN
# Population                                                       NaN
# HPI                                                              NaN
#
#                                                                   9   ...  \
# BEGIN_YEARMONTH                                               202202  ...
# BEGIN_TIME                                                       400  ...
# STATE                                                  MASSACHUSETTS  ...
# YEAR                                                            2022  ...
# MONTH_NAME                                                  February  ...
# EVENT_TYPE                                                Heavy Snow  ...
# BEGIN_DATE_TIME                                  2022-02-13 04:00:00  ...
# INJURIES_DIRECT                                                    0  ...
# INJURIES_INDIRECT                                                  0  ...
# DEATHS_DIRECT                                                      0  ...
# DEATHS_INDIRECT                                                    0  ...
# DAMAGE_PROPERTY                                                  0.0  ...
# MAGNITUDE                                                        0.0  ...
# MAGNITUDE_TYPE                                                  None  ...
# FLOOD_CAUSE                                                     None  ...
# TOR_F_SCALE                                                     None  ...
# TOR_LENGTH                                                       0.0  ...
# TOR_WIDTH                                                        0.0  ...
# BEGIN_LAT                                                        NaN  ...
# BEGIN_LON                                                        NaN  ...
# EPISODE_NARRATIVE  A low pressure system tracked offshore of Sout...  ...
# EVENT_NARRATIVE    Snowfall was generally 6 to 8 inches. The high...  ...
# ST_CT_FIPS                                                     25013  ...
# DURATION                                                     1,680.0  ...
# STORM_AREA                                                       NaN  ...
# PopDensity                                               293.5650603  ...
# Population                                                 465,834.0  ...
# HPI                                                        104,146.0  ...
#
#                                                                   30  \
# BEGIN_YEARMONTH                                               202201
# BEGIN_TIME                                                      1200
# STATE                                                           OHIO
# YEAR                                                            2022
# MONTH_NAME                                                   January
# EVENT_TYPE                                            Winter Weather
# BEGIN_DATE_TIME                                  2022-01-16 12:00:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        0.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                        NaN
# BEGIN_LON                                                        NaN
# EPISODE_NARRATIVE  A low pressure system tracked northeast throug...
# EVENT_NARRATIVE    The observer south of Jeffersonville measured ...
# ST_CT_FIPS                                                     39063
# DURATION                                                     1,140.0
# STORM_AREA                                                       NaN
# PopDensity                                               55.00347628
# Population                                                  74,926.0
# HPI                                                         57,545.0
#
#                                                                   31  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1811
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                                      Hail
# BEGIN_DATE_TIME                                  2022-08-29 18:11:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                        1.0
# MAGNITUDE_TYPE                                                  None
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      40.99
# BEGIN_LON                                                     -88.73
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE                                                 None
# ST_CT_FIPS                                                     17105
# DURATION                                                         1.0
# STORM_AREA                                                       0.0
# PopDensity                                               13.43849744
# Population                                                  35,816.0
# HPI                                                         26,927.0
#
#                                                                   32  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1839
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 18:39:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       55.0
# MAGNITUDE_TYPE                                                    EG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      40.86
# BEGIN_LON                                                      -88.6
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE                                  A tree was snapped.
# ST_CT_FIPS                                                     17105
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               13.43849744
# Population                                                  35,816.0
# HPI                                                         26,927.0
#
#                                                                   33  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1839
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 18:39:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       55.0
# MAGNITUDE_TYPE                                                    EG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    40.8887
# BEGIN_LON                                                   -88.5955
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    A utility pole and power lines were blown down...
# ST_CT_FIPS                                                     17105
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               13.43849744
# Population                                                  35,816.0
# HPI                                                         26,927.0
#
#                                                                   34  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1225
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 12:25:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       64.0
# MAGNITUDE_TYPE                                                    MG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    41.3397
# BEGIN_LON                                                   -87.7467
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    A private weather station measured a wind gust...
# ST_CT_FIPS                                                     17197
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               318.1154816
# Population                                                 696,362.0
# HPI                                                         49,348.0
#
#                                                                   35  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1220
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 12:20:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       60.0
# MAGNITUDE_TYPE                                                    EG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    41.3388
# BEGIN_LON                                                   -87.8001
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    Widespread tree damage was reported on the nor...
# ST_CT_FIPS                                                     17197
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               318.1154816
# Population                                                 696,362.0
# HPI                                                         49,348.0
#
#                                                                   36  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1218
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 12:18:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       50.0
# MAGNITUDE_TYPE                                                    EG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    41.3243
# BEGIN_LON                                                    -87.822
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    Large tree limbs were blown down near Intersta...
# ST_CT_FIPS                                                     17197
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               318.1154816
# Population                                                 696,362.0
# HPI                                                         49,348.0
#
#                                                                   37  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1224
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 12:24:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       60.0
# MAGNITUDE_TYPE                                                    MG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    41.3332
# BEGIN_LON                                                   -87.7895
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    A wind gust to 69 mph was measured 35 feet abo...
# ST_CT_FIPS                                                     17197
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               318.1154816
# Population                                                 696,362.0
# HPI                                                         49,348.0
#
#                                                                   38  \
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1224
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 12:24:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       55.0
# MAGNITUDE_TYPE                                                    EG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                    41.1549
# BEGIN_LON                                                   -87.8712
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    Multiple large tree limbs were broken at the O...
# ST_CT_FIPS                                                     17091
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               63.38660191
# Population                                                 107,508.0
# HPI                                                         33,508.0
#
#                                                                   39
# BEGIN_YEARMONTH                                               202208
# BEGIN_TIME                                                      1230
# STATE                                                       ILLINOIS
# YEAR                                                            2022
# MONTH_NAME                                                    August
# EVENT_TYPE                                         Thunderstorm Wind
# BEGIN_DATE_TIME                                  2022-08-29 12:30:00
# INJURIES_DIRECT                                                    0
# INJURIES_INDIRECT                                                  0
# DEATHS_DIRECT                                                      0
# DEATHS_INDIRECT                                                    0
# DAMAGE_PROPERTY                                                  0.0
# MAGNITUDE                                                       60.0
# MAGNITUDE_TYPE                                                    EG
# FLOOD_CAUSE                                                     None
# TOR_F_SCALE                                                     None
# TOR_LENGTH                                                       0.0
# TOR_WIDTH                                                        0.0
# BEGIN_LAT                                                      41.24
# BEGIN_LON                                                     -87.65
# EPISODE_NARRATIVE  Thunderstorms moved across northern Illinois d...
# EVENT_NARRATIVE    Trees and tree limbs were blown down.  A 6 to ...
# ST_CT_FIPS                                                     17091
# DURATION                                                         0.0
# STORM_AREA                                                       0.0
# PopDensity                                               63.38660191
# Population                                                 107,508.0
# HPI                                                         33,508.0
#
# [28 rows x 40 columns]

# %%
# remove columns that won't have any predictive value
df = df.drop(['ST_CT_FIPS', 'EVENT_NARRATIVE', 'EPISODE_NARRATIVE', 'BEGIN_LON', 'BEGIN_LAT', 'BEGIN_DATE_TIME', 'MONTH_NAME', 'YEAR', 'BEGIN_YEARMONTH', 'MAGNITUDE_TYPE', 'TOR_F_SCALE'], axis=1)

# %%
# drop columns that have a lot of missing values
df = df.drop(['FLOOD_CAUSE', 'INJURIES_DIRECT', 'INJURIES_INDIRECT'], axis=1)

# %% [markdown]
# ### Part 2 of dropping columns

# %%
# started by dropping begin_time and state
#df = df.drop(['BEGIN_TIME', 'STATE'], axis=1)

# drop begin time, state, population
#df = df.drop(['BEGIN_TIME', 'STATE', 'Population'], axis=1)

# drop begin time, state, population, indirect deaths
df = df.drop(['BEGIN_TIME', 'STATE', 'Population', 'DEATHS_INDIRECT'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555647 entries, 0 to 1555646
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   EVENT_TYPE       1555647 non-null  object
#  1   DEATHS_DIRECT    1555647 non-null  int64
#  2   DAMAGE_PROPERTY  1555647 non-null  float64
#  3   MAGNITUDE        1555647 non-null  float64
#  4   TOR_LENGTH       1555647 non-null  float64
#  5   TOR_WIDTH        1555647 non-null  float64
#  6   DURATION         1555647 non-null  float64
#  7   STORM_AREA       916584 non-null   float64
#  8   PopDensity       1035753 non-null  float64
#  9   HPI              1051529 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 130.6+ MB

# %%
df.DAMAGE_PROPERTY.value_counts()
# Out:
# 0.0              1208379
# 5,000.0            44298
# 1,000.0            42880
# 10,000.0           37586
# 2,000.0            30523
#                   ...
# 124,000,000.0          1
# 1,710,000.0            1
# 3,850.0                1
# 81,000,000.0           1
# 322,200.0              1
# Name: DAMAGE_PROPERTY, Length: 2060, dtype: int64

# %%
len(df)
# Out:
# 1555647

# %%
#df = df[df['DAMAGE_PROPERTY'] > 0]

# %%
len(df)
# Out:
# 347268

# %%
df = df.sort_values(by=['DAMAGE_PROPERTY'], ascending=False)

# %%
# remove outliers
df = df[5000:]

# %%
len(df)
# Out:
# 346755

# %%
df['DAMAGE_PROPERTY'].mean()
# Out:
# 312800.4221712737

# %%
df['DAMAGE_PROPERTY'].median()
# Out:
# 8000.0

# %%
df.describe()
# Out:
#              DEATHS_DIRECT      DAMAGE_PROPERTY          MAGNITUDE  \
# count            346,755.0            346,755.0          346,755.0
# mean  0.011818142492537959   312,800.4221712737  29.77186157373464
# std     0.3368504847978087 3,252,968.4597323965 27.190256957454633
# min                    0.0                 10.0                0.0
# 25%                    0.0              2,000.0                0.0
# 50%                    0.0              8,000.0               45.0
# 75%                    0.0             25,000.0               52.0
# max                   93.0        100,000,000.0            3,430.0
#
#                TOR_LENGTH          TOR_WIDTH           DURATION  \
# count           346,755.0          346,755.0          346,755.0
# mean  0.19717200905538423 10.458819483497003  537.9875474037865
# std    1.4934240824298446  79.98551041120477 5,107.161099603181
# min                   0.0                0.0                0.0
# 25%                   0.0                0.0                0.0
# 50%                   0.0                0.0                2.0
# 75%                   0.0                0.0              120.0
# max                 300.0            4,576.0          505,439.0
#
#                  STORM_AREA        PopDensity                 HPI
# count             267,835.0         284,051.0           290,945.0
# mean   0.013220355704072996 146.2972730016975 27,557.819680695666
# std    0.048679416284456434 702.7921841946905  20,759.24977234603
# min                     0.0      0.1878698513                92.0
# 25%                     0.0       15.03833828            15,222.0
# 50%                     0.0        34.2392392            22,286.0
# 75%   0.0008999999999943498       103.6373274            34,819.0
# max                     2.5       27,819.8048           203,517.0

# %%
df.head(10)
# Out:
#                   EVENT_TYPE  DEATHS_DIRECT  DAMAGE_PROPERTY  MAGNITUDE  \
# 341920           Flash Flood              0    100,000,000.0        0.0
# 387051               Tornado              7    100,000,000.0        0.0
# 1338820          Flash Flood              0    100,000,000.0        0.0
# 1086480  Hurricane (Typhoon)              0    100,000,000.0        0.0
# 1086482  Hurricane (Typhoon)              0    100,000,000.0        0.0
# 1491637     Storm Surge/Tide              0    100,000,000.0        0.0
# 836181             Hurricane              0    100,000,000.0        0.0
# 148128               Tornado              1    100,000,000.0        0.0
# 1249806          Flash Flood              0    100,000,000.0        0.0
# 428855                  Hail              0    100,000,000.0        3.0
#
#          TOR_LENGTH  TOR_WIDTH  DURATION          STORM_AREA  PopDensity  \
# 341920          0.0        0.0     315.0                 0.0 55.00347628
# 387051          6.5      400.0      10.0 0.02039999999999509 81.28457967
# 1338820         0.0        0.0     180.0 0.13149999999999906 116.2599464
# 1086480         0.0        0.0   1,080.0                 NaN 9.458934503
# 1086482         0.0        0.0     300.0                 NaN         NaN
# 1491637         0.0        0.0     900.0                 NaN         NaN
# 836181          0.0        0.0   1,800.0                 NaN         NaN
# 148128         19.5    4,400.0      35.0   0.183329999999998 142.9473945
# 1249806         0.0        0.0   1,430.0                 NaN 36.51369922
# 428855          0.0        0.0      33.0  0.1893000000000029  129.959318
#
#              HPI
# 341920  40,173.0
# 387051  26,526.0
# 1338820 41,675.0
# 1086480 18,349.0
# 1086482 19,995.0
# 1491637      NaN
# 836181  31,503.0
# 148128  37,098.0
# 1249806 22,222.0
# 428855  43,828.0

# %%
df['DAMAGE_PROPERTY'].describe()
# Out:
# count              346,755.0
# mean      312,800.4221712737
# std     3,252,968.4597323965
# min                     10.0
# 25%                  2,000.0
# 50%                  8,000.0
# 75%                 25,000.0
# max            100,000,000.0
# Name: DAMAGE_PROPERTY, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346755 entries, 341920 to 271313
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   EVENT_TYPE       346755 non-null  object
#  1   DEATHS_DIRECT    346755 non-null  int64
#  2   DAMAGE_PROPERTY  346755 non-null  float64
#  3   MAGNITUDE        346755 non-null  float64
#  4   TOR_LENGTH       346755 non-null  float64
#  5   TOR_WIDTH        346755 non-null  float64
#  6   DURATION         346755 non-null  float64
#  7   STORM_AREA       267835 non-null  float64
#  8   PopDensity       284051 non-null  float64
#  9   HPI              290945 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 29.1+ MB

# %%
# fill storm area nulls with zero
#df['STORM_AREA'] = df['STORM_AREA'].fillna(0)

# %%
df.head(30)
# Out:
#                   EVENT_TYPE  DEATHS_DIRECT  DAMAGE_PROPERTY  MAGNITUDE  \
# 341920           Flash Flood              0    100,000,000.0        0.0
# 387051               Tornado              7    100,000,000.0        0.0
# 1338820          Flash Flood              0    100,000,000.0        0.0
# 1086480  Hurricane (Typhoon)              0    100,000,000.0        0.0
# 1086482  Hurricane (Typhoon)              0    100,000,000.0        0.0
# 1491637     Storm Surge/Tide              0    100,000,000.0        0.0
# 836181             Hurricane              0    100,000,000.0        0.0
# 148128               Tornado              1    100,000,000.0        0.0
# 1249806          Flash Flood              0    100,000,000.0        0.0
# 428855                  Hail              0    100,000,000.0        3.0
# 1488559  Hurricane (Typhoon)              1    100,000,000.0        0.0
# 1181050                Flood              0    100,000,000.0        0.0
# 1489016  Hurricane (Typhoon)              1    100,000,000.0        0.0
# 916668             High Wind              0    100,000,000.0       57.0
# 1086849  Hurricane (Typhoon)              0    100,000,000.0        0.0
# 1051942              Tornado              0    100,000,000.0        0.0
# 1278656                 Hail              0    100,000,000.0       1.75
# 1176443             Wildfire              0    100,000,000.0        0.0
# 1552475              Tornado              0    100,000,000.0        0.0
# 418531           Flash Flood              0    100,000,000.0        0.0
# 418828           Flash Flood              0    100,000,000.0        0.0
# 411520               Tornado             19    100,000,000.0        0.0
# 835006           Flash Flood             19    100,000,000.0        0.0
# 231801           Flash Flood             19    100,000,000.0        0.0
# 916659             High Wind              2    100,000,000.0       59.0
# 1492413  Hurricane (Typhoon)              0    100,000,000.0        0.0
# 1336411          Flash Flood             10    100,000,000.0        0.0
# 836574             Hurricane              0    100,000,000.0        0.0
# 85199            Flash Flood              2    100,000,000.0        0.0
# 1488557  Hurricane (Typhoon)              0    100,000,000.0        0.0
#
#          TOR_LENGTH  TOR_WIDTH  DURATION            STORM_AREA  PopDensity  \
# 341920          0.0        0.0     315.0                   0.0 55.00347628
# 387051          6.5      400.0      10.0   0.02039999999999509 81.28457967
# 1338820         0.0        0.0     180.0   0.13149999999999906 116.2599464
# 1086480         0.0        0.0   1,080.0                   NaN 9.458934503
# 1086482         0.0        0.0     300.0                   NaN         NaN
# 1491637         0.0        0.0     900.0                   NaN         NaN
# 836181          0.0        0.0   1,800.0                   NaN         NaN
# 148128         19.5    4,400.0      35.0     0.183329999999998 142.9473945
# 1249806         0.0        0.0   1,430.0                   NaN 36.51369922
# 428855          0.0        0.0      33.0    0.1893000000000029  129.959318
# 1488559         0.0        0.0     930.0                   NaN         NaN
# 1181050         0.0        0.0  44,639.0   0.00999999999999801 13.24099277
# 1489016         0.0        0.0     930.0                   NaN         NaN
# 916668          0.0        0.0     600.0                   NaN         NaN
# 1086849         0.0        0.0     720.0                   NaN 208.7663614
# 1051942        7.61      125.0       8.0   0.05530000000000257 67.69833274
# 1278656         0.0        0.0      15.0                   0.0 97.47807618
# 1176443         0.0        0.0  23,699.0                   NaN 5.559697453
# 1552475         6.0      500.0      13.0                   0.0 4.399986391
# 418531          0.0        0.0     832.0   0.14000000000000057 62.36493775
# 418828          0.0        0.0     937.0   0.10999999999999943 62.36493775
# 411520         8.39      900.0       8.0 0.0005999999999986017  73.5806145
# 835006          0.0        0.0       0.0  0.006199999999999761 13.32539223
# 231801          0.0        0.0       0.0  0.006199999999999761 13.32539223
# 916659          0.0        0.0     480.0                   NaN  348.783328
# 1492413         0.0        0.0     930.0                   NaN         NaN
# 1336411         0.0        0.0     182.0   0.05109999999999815 116.2599464
# 836574          0.0        0.0   1,800.0                   NaN         NaN
# 85199           0.0        0.0   1,020.0                   NaN 43.00662407
# 1488557         0.0        0.0     930.0                   NaN         NaN
#
#              HPI
# 341920  40,173.0
# 387051  26,526.0
# 1338820 41,675.0
# 1086480 18,349.0
# 1086482 19,995.0
# 1491637      NaN
# 836181  31,503.0
# 148128  37,098.0
# 1249806 22,222.0
# 428855  43,828.0
# 1488559      NaN
# 1181050 41,782.0
# 1489016      NaN
# 916668       NaN
# 1086849  2,942.0
# 1051942 23,927.0
# 1278656 37,539.0
# 1176443 16,648.0
# 1552475    100.0
# 418531  23,848.0
# 418828  23,848.0
# 411520  28,444.0
# 835006  30,322.0
# 231801  30,322.0
# 916659  51,034.0
# 1492413      NaN
# 1336411 41,675.0
# 836574       NaN
# 85199   17,609.0
# 1488557      NaN

# %%
df.shape
# Out:
# (346755, 10)

# %%
df.isna().sum().sum()
# Out:
# 197434

# %%
# drop rows with null values
df = df.dropna(axis=0).reset_index()
df = df.drop(['index'], axis=1)
# y_train = y_train.dropna(axis=0)
# y_test = y_test.dropna(axis=0)

# %%
df.shape
# Out:
# (239894, 10)

# %%
# when including storm size fill to zero
1011673
# Out:
# 1011673

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239894 entries, 0 to 239893
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   EVENT_TYPE       239894 non-null  object
#  1   DEATHS_DIRECT    239894 non-null  int64
#  2   DAMAGE_PROPERTY  239894 non-null  float64
#  3   MAGNITUDE        239894 non-null  float64
#  4   TOR_LENGTH       239894 non-null  float64
#  5   TOR_WIDTH        239894 non-null  float64
#  6   DURATION         239894 non-null  float64
#  7   STORM_AREA       239894 non-null  float64
#  8   PopDensity       239894 non-null  float64
#  9   HPI              239894 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 18.3+ MB

# %% [markdown]
# ## Create dummy variables for categorical data types

# %%
# isolate categorical variables
categorical_features = df.select_dtypes(include=['object'])

# %%
df = pd.concat([df.drop(categorical_features, axis=1), pd.get_dummies(categorical_features)], axis=1)

# %% [markdown]
# ### Split data into training and testing subsets

# %%
# Create the X and y matrices from the dataframe
X = df.drop(columns = ['DAMAGE_PROPERTY'])
y = df['DAMAGE_PROPERTY']

# %%
# from sklearn.model_selection import train_test_split; reserve 20% for test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=1234)

# %%
#X_train.isna().sum().sum()

# %% [markdown]
# ## Scaling and Transforming Numeric Features

# %%
# Create subset of only the numeric columns
numeric_df = df.select_dtypes(include=['int', 'float'])
numeric_df = numeric_df.drop(columns = ['DAMAGE_PROPERTY'])

# %%
numeric_column_names = list(numeric_df.columns)

# %%
# let's look at the distribution of numeric variables
numeric_df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5)

# %%
# isolate numeric features of X_train and X_test
numeric_df_X_train = X_train.select_dtypes(include=['int', 'float'])
numeric_df_X_test = X_test.select_dtypes(include=['int', 'float'])

# %%
#numeric_df_X_test.isna().sum().sum()

# %% [markdown]
# ### Let's try standardize features with StandardScaler
# - Less sensitive to outliers (we know we have a number of significant outliers)

# %%
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# create model, fit, and transform
SS_scaler = StandardScaler()
numeric_df_ss_X_train = SS_scaler.fit_transform(numeric_df_X_train)
numeric_df_ss_X_test = SS_scaler.fit_transform(numeric_df_X_test)

# convert back to dataframe for plotting
numeric_df_ss_X_train = pd.DataFrame(numeric_df_ss_X_train)
numeric_df_ss_X_train.columns = numeric_column_names
numeric_df_ss_X_test = pd.DataFrame(numeric_df_ss_X_test)
numeric_df_ss_X_test.columns = numeric_column_names

numeric_df_ss_X_train.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# #### Update numeric column values with the Standardized values

# %%
# reset index
X_train = X_train.reset_index()
# drop extra column
X_train = X_train.drop(['index'], axis=1)

# %%
X_test = X_test.reset_index()
X_test = X_test.drop(['index'], axis=1)

# %%
for column_name in numeric_column_names:
    X_train[column_name] = numeric_df_ss_X_train[column_name]

# %%
for column_name in numeric_column_names:
    X_test[column_name] = numeric_df_ss_X_test[column_name]

# %%
X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])

# %% [markdown]
# ### Look at correlation matrix to see if relationships are still preserved after transformations

# %%
df2 = X

# %%
df2.head()
# Out:
#           DEATHS_DIRECT           MAGNITUDE           TOR_LENGTH  \
# 0 -0.041888316205157504  0.6351158758065769 -0.15850301628143004
# 1 -0.041888316205157504 -1.2668621974867313 -0.15850301628143004
# 2 -0.041888316205157504  1.2057092977945694 -0.15850301628143004
# 3 -0.041888316205157504  0.4449180684772461 -0.15850301628143004
# 4 -0.041888316205157504  0.6351158758065769 -0.15850301628143004
#
#             TOR_WIDTH             DURATION           STORM_AREA  \
# 0 -0.1465483687546355  -0.1157120708045282 -0.27530670577458166
# 1 -0.1465483687546355 -0.11652141680391066 -0.27530670577458166
# 2 -0.1465483687546355 -0.11045132180854217 -0.27530670577458166
# 3 -0.1465483687546355 -0.11652141680391066 -0.27530670577458166
# 4 -0.1465483687546355 -0.11652141680391066 -0.27530670577458166
#
#             PopDensity                 HPI  EVENT_TYPE_Debris Flow  \
# 0 -0.24221967159456076 -0.4022614919527665                       0
# 1 -0.19219010748923593 -0.4513344870589856                       0
# 2  0.09821992489169953  0.5070901475531493                       0
# 3 -0.24098207643269856 -0.8442137718512032                       0
# 4  -0.0633494471024798 0.38300487106089415                       0
#
#    EVENT_TYPE_Dust Devil  EVENT_TYPE_Flash Flood  EVENT_TYPE_Flood  \
# 0                      0                       0                 0
# 1                      0                       0                 0
# 2                      0                       0                 0
# 3                      0                       0                 0
# 4                      0                       0                 0
#
#    EVENT_TYPE_Funnel Cloud  EVENT_TYPE_Hail  EVENT_TYPE_Heavy Rain  \
# 0                        0                0                      0
# 1                        0                0                      0
# 2                        0                0                      0
# 3                        0                0                      0
# 4                        0                0                      0
#
#    EVENT_TYPE_High Wind  EVENT_TYPE_Lightning  EVENT_TYPE_Thunderstorm Wind  \
# 0                     0                     0                             1
# 1                     0                     1                             0
# 2                     0                     0                             1
# 3                     0                     0                             1
# 4                     0                     0                             1
#
#    EVENT_TYPE_Tornado
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
df2['DAMAGE_PROPERTY'] = y

# %%
df2.head()
# Out:
#           DEATHS_DIRECT           MAGNITUDE           TOR_LENGTH  \
# 0 -0.041888316205157504  0.6351158758065769 -0.15850301628143004
# 1 -0.041888316205157504 -1.2668621974867313 -0.15850301628143004
# 2 -0.041888316205157504  1.2057092977945694 -0.15850301628143004
# 3 -0.041888316205157504  0.4449180684772461 -0.15850301628143004
# 4 -0.041888316205157504  0.6351158758065769 -0.15850301628143004
#
#             TOR_WIDTH             DURATION           STORM_AREA  \
# 0 -0.1465483687546355  -0.1157120708045282 -0.27530670577458166
# 1 -0.1465483687546355 -0.11652141680391066 -0.27530670577458166
# 2 -0.1465483687546355 -0.11045132180854217 -0.27530670577458166
# 3 -0.1465483687546355 -0.11652141680391066 -0.27530670577458166
# 4 -0.1465483687546355 -0.11652141680391066 -0.27530670577458166
#
#             PopDensity                 HPI  EVENT_TYPE_Debris Flow  \
# 0 -0.24221967159456076 -0.4022614919527665                       0
# 1 -0.19219010748923593 -0.4513344870589856                       0
# 2  0.09821992489169953  0.5070901475531493                       0
# 3 -0.24098207643269856 -0.8442137718512032                       0
# 4  -0.0633494471024798 0.38300487106089415                       0
#
#    EVENT_TYPE_Dust Devil  EVENT_TYPE_Flash Flood  EVENT_TYPE_Flood  \
# 0                      0                       0                 0
# 1                      0                       0                 0
# 2                      0                       0                 0
# 3                      0                       0                 0
# 4                      0                       0                 0
#
#    EVENT_TYPE_Funnel Cloud  EVENT_TYPE_Hail  EVENT_TYPE_Heavy Rain  \
# 0                        0                0                      0
# 1                        0                0                      0
# 2                        0                0                      0
# 3                        0                0                      0
# 4                        0                0                      0
#
#    EVENT_TYPE_High Wind  EVENT_TYPE_Lightning  EVENT_TYPE_Thunderstorm Wind  \
# 0                     0                     0                             1
# 1                     0                     1                             0
# 2                     0                     0                             1
# 3                     0                     0                             1
# 4                     0                     0                             1
#
#    EVENT_TYPE_Tornado  DAMAGE_PROPERTY
# 0                   0    100,000,000.0
# 1                   0    100,000,000.0
# 2                   0    100,000,000.0
# 3                   0    100,000,000.0
# 4                   0    100,000,000.0

# %%
# before dropping columns # df2_corr = df2[['BEGIN_TIME','DEATHS_DIRECT', 'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'MAGNITUDE', 'TOR_LENGTH', 'TOR_WIDTH', 'DURATION', 'STORM_AREA', 'PopDensity', 'Population', 'HPI']]
df2_corr = df2[['DEATHS_DIRECT', 'DAMAGE_PROPERTY', 'MAGNITUDE', 'TOR_LENGTH', 'TOR_WIDTH', 'DURATION', 'STORM_AREA', 'PopDensity', 'HPI']]

# %%
corrmat = df2_corr.corr()
f, ax = plt.subplots(figsize=(8, 6))
hm = sns.heatmap(round(corrmat,2), annot=True, ax=ax, cmap='magma',fmt='.2f',
                 linewidths=.05)
#hm = sns.heatmap(round(corrmat,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
#                 linewidths=.05)

f.subplots_adjust(top=0.93)
#t= f.suptitle('Match Data Feature Correlation for all USA matches', fontsize=14)

# %% [markdown]
# Looks like the relationships are largely in tact

# %%
# convert y_test and y_train to dataframes so they can be written to file
y_test = pd.DataFrame(y_test)
y_train = pd.DataFrame(y_train)

# %% [markdown]
# #### write to parquest - 4 files

# %%
from pathlib import Path  
filepath = Path('../Data/X_train.pqt')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
X_train.to_parquet(filepath)

# %%
from pathlib import Path  
filepath = Path('../Data/X_test.pqt')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
X_test.to_parquet(filepath)

# %%
from pathlib import Path  
filepath = Path('../Data/y_train.pqt')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
y_train.to_parquet(filepath)

# %%
from pathlib import Path  
filepath = Path('../Data/y_test.pqt')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
y_test.to_parquet(filepath)

# %% [markdown]
# ## SweetViz

# %%
#y_train = y_train.reset_index(drop=True)

# %%
#y_train.head()

# %%
#train = X_train

# %%
#train['DAMAGE_PROPERTY'] = y_train

# %%
#train

# %%
#my_report = sweetviz.analyze([train, "Train"],target_feat='DAMAGE_PROPERTY')

# %%
#my_report.show_html('Report.html')
